# %%
import os
import pandas as pd
import requests
from bs4 import BeautifulSoup
import nltk
import re
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('punkt')

# Load input file
input_file = "Input.xlsx"
df = pd.read_excel(input_file)

# Load stopwords
stopwords_folder = "StopWords"
stopwords_files = os.listdir(stopwords_folder)

stopwords = set()
for file in stopwords_files:
    with open(os.path.join(stopwords_folder, file), "r", encoding="ISO-8859-1") as f:
        stopwords.update(f.read().split())

# Load positive and negative words
def load_dictionary(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        return set(f.read().split())

positive_words = load_dictionary("MasterDictionary/positive-words.txt")
def load_dictionary(file_path):
    with open(file_path, "r", encoding="ISO-8859-1") as f:  # Change encoding
        return set(f.read().split())

negative_words = load_dictionary("MasterDictionary/negative-words.txt")


# Function to extract text from a URL
def extract_text(url):
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")

        # Extract title and article content
        title = soup.find("h1").get_text(strip=True) if soup.find("h1") else "No Title"
        paragraphs = soup.find_all("p")
        content = " ".join([p.get_text(strip=True) for p in paragraphs])

        return title + "\n\n" + content
    except Exception as e:
        print(f"Error extracting {url}: {e}")
        return None

# Function to preprocess text
def preprocess_text(text):
    words = word_tokenize(text.lower())
    words = [w for w in words if w.isalnum() and w not in stopwords]
    return words

# Function to count syllables in a word
def count_syllables(word):
    vowels = "aeiou"
    count = sum(1 for char in word if char in vowels)
    if word.endswith(("es", "ed")):
        count -= 1
    return max(count, 1)

# Function to analyze text and compute scores
def analyze_text(text):
    words = preprocess_text(text)
    sentences = sent_tokenize(text)

    pos_score = sum(1 for w in words if w in positive_words)
    neg_score = sum(1 for w in words if w in negative_words) * -1
    polarity_score = (pos_score - neg_score) / ((pos_score + neg_score) + 0.000001)
    subjectivity_score = (pos_score + neg_score) / (len(words) + 0.000001)

    avg_sentence_length = len(words) / max(len(sentences), 1)
    complex_words = [w for w in words if count_syllables(w) > 2]
    percentage_complex_words = len(complex_words) / len(words) if words else 0
    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)

    avg_words_per_sentence = len(words) / max(len(sentences), 1)
    complex_word_count = len(complex_words)
    word_count = len(words)
    syllables_per_word = sum(count_syllables(w) for w in words) / len(words) if words else 0
    personal_pronouns = len(re.findall(r'\b(I|we|my|ours|us)\b', text, re.IGNORECASE))
    avg_word_length = sum(len(w) for w in words) / len(words) if words else 0

    return {
        "POSITIVE SCORE": pos_score,
        "NEGATIVE SCORE": abs(neg_score),
        "POLARITY SCORE": polarity_score,
        "SUBJECTIVITY SCORE": subjectivity_score,
        "AVG SENTENCE LENGTH": avg_sentence_length,
        "PERCENTAGE OF COMPLEX WORDS": percentage_complex_words,
        "FOG INDEX": fog_index,
        "AVG NUMBER OF WORDS PER SENTENCE": avg_words_per_sentence,
        "COMPLEX WORD COUNT": complex_word_count,
        "WORD COUNT": word_count,
        "SYLLABLE PER WORD": syllables_per_word,
        "PERSONAL PRONOUNS": personal_pronouns,
        "AVG WORD LENGTH": avg_word_length
    }

# Process all URLs and save results
output_data = []

for index, row in df.iterrows():
    url_id = row["URL_ID"]
    url = row["URL"]

    print(f"Processing URL_ID: {url_id}")

    text = extract_text(url)
    if text:
        with open(f"{url_id}.txt", "w", encoding="utf-8") as f:
            f.write(text)

        analysis = analyze_text(text)
        output_data.append({
            "URL_ID": url_id,
            "URL": url,
            **analysis
        })

# Save results to Excel
output_df = pd.DataFrame(output_data)
output_df.to_excel("Output.xlsx", index=False)

print("Processing complete! Results saved in Output.xlsx")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\YADUV\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Processing URL_ID: Netclan20241017
# Error extracting https://insights.blackcoffer.com/ai-and-ml-based-youtube-analytics-and-content-creation-tool-for-optimizing-subscriber-engagement-and-content-strategy/: HTTPSConnectionPool(host='insights.blackcoffer.com', port=443): Read timed out. (read timeout=10)
# Processing URL_ID: Netclan20241018
# Processing URL_ID: Netclan20241019
# Processing URL_ID: Netclan20241020
# Processing URL_ID: Netclan20241021
# Processing URL_ID: Netclan20241022
# Processing URL_ID: Netclan20241023
# Processing URL_ID: Netclan20241024
# Processing URL_ID: Netclan20241025
# Processing URL_ID: Netclan20241026
# Processing URL_ID: Netclan20241027
# Processing URL_ID: Netclan20241028
# Processing URL_ID: Netclan20241029
# Processing URL_ID: Netclan20241030
# Processing URL_ID: Netclan20241031
# Processing URL_ID: Netclan20241032
# Processing URL_ID: Netclan20241033
# Processing URL_ID: Netclan20241034
# Processing URL_ID: Netclan20241035
# Processing URL_ID: Netclan20241036
# Processing URL_ID: Netclan20241037
# Processing URL_ID: Netclan20241038
# Processing URL_ID: Netclan20241039
# Processing URL_ID: Netclan20241040
# Processing URL_ID: Netclan20241041
# Processing URL_ID: Netclan20241042
# Processing URL_ID: Netclan20241043
# Processing URL_ID: Netclan20241044
# Processing URL_ID: Netclan20241045
# Processing URL_ID: Netclan20241046
# Processing URL_ID: Netclan20241047
# Processing URL_ID: Netclan20241048
# Processing URL_ID: Netclan20241049
# Processing URL_ID: Netclan20241050
# Processing URL_ID: Netclan20241051
# Processing URL_ID: Netclan20241052
# Processing URL_ID: Netclan20241053
# Processing URL_ID: Netclan20241054
# Processing URL_ID: Netclan20241055
# Processing URL_ID: Netclan20241056
# Processing URL_ID: Netclan20241057
# Processing URL_ID: Netclan20241058
# Processing URL_ID: Netclan20241059
# Processing URL_ID: Netclan20241060
# Processing URL_ID: Netclan20241061
# Processing URL_ID: Netclan20241062
# Processing URL_ID: Netclan20241063
# Processing URL_ID: Netclan20241064
# Processing URL_ID: Netclan20241065
# Processing URL_ID: Netclan20241066
# Processing URL_ID: Netclan20241067
# Processing URL_ID: Netclan20241068
# Processing URL_ID: Netclan20241069
# Processing URL_ID: Netclan20241070
# Processing URL_ID: Netclan20241071
# Processing URL_ID: Netclan20241072
# Processing URL_ID: Netclan20241073
# Processing URL_ID: Netclan20241074
# Processing URL_ID: Netclan20241075
# Processing URL_ID: Netclan20241076
# Processing URL_ID: Netclan20241077
# Processing URL_ID: Netclan20241078
# Processing URL_ID: Netclan20241079
# Processing URL_ID: Netclan20241080
# Processing URL_ID: Netclan20241081
# Processing URL_ID: Netclan20241082
# Processing URL_ID: Netclan20241083
# Processing URL_ID: Netclan20241084
# Processing URL_ID: Netclan20241085
# Processing URL_ID: Netclan20241086
# Processing URL_ID: Netclan20241087
# Processing URL_ID: Netclan20241088
# Processing URL_ID: Netclan20241089
# Processing URL_ID: Netclan20241090
# Processing URL_ID: Netclan20241091
# Processing URL_ID: Netclan20241092
# Processing URL_ID: Netclan20241093
# Processing URL_ID: Netclan20241094
# Processing URL_ID: Netclan20241095
# Processing URL_ID: Netclan20241096
# Processing URL_ID: Netclan20241097
# Processing URL_ID: Netclan20241098
# Processing URL_ID: Netclan20241099
# Processing URL_ID: Netclan20241100
# Processing URL_ID: Netclan20241101
# Processing URL_ID: Netclan20241102
# Processing URL_ID: Netclan20241103
# Processing URL_ID: Netclan20241104
# Processing URL_ID: Netclan20241105
# Processing URL_ID: Netclan20241106
# Processing URL_ID: Netclan20241107
# Processing URL_ID: Netclan20241108
# Processing URL_ID: Netclan20241109
# Processing URL_ID: Netclan20241110
# Processing URL_ID: Netclan20241111
# Processing URL_ID: Netclan20241112
# Processing URL_ID: Netclan20241113
# Processing URL_ID: Netclan20241114
# Processing URL_ID: Netclan20241115
# Processing URL_ID: Netclan20241116
# Processing URL_ID: Netclan20241117
# Processing URL_ID: Netclan20241118
# Processing URL_ID: Netclan20241119
# Processing URL_ID: Netclan20241120
# Processing URL_ID: Netclan20241121
# Processing URL_ID: Netclan20241122
# Processing URL_ID: Netclan20241123
# Processing URL_ID: Netclan20241124
# Processing URL_ID: Netclan20241125
# Processing URL_ID: Netclan20241126
# Processing URL_ID: Netclan20241127
# Processing URL_ID: Netclan20241128
# Processing URL_ID: Netclan20241129
# Processing URL_ID: Netclan20241130
# Processing URL_ID: Netclan20241131
# Processing URL_ID: Netclan20241132
# Processing URL_ID: Netclan20241133
# Processing URL_ID: Netclan20241134
# Processing URL_ID: Netclan20241135
# Processing URL_ID: Netclan20241136
# Processing URL_ID: Netclan20241137
# Processing URL_ID: Netclan20241138
# Processing URL_ID: Netclan20241139
# Processing URL_ID: Netclan20241140
# Processing URL_ID: Netclan20241141
# Processing URL_ID: Netclan20241142
# Processing URL_ID: Netclan20241143
# Processing URL_ID: Netclan20241144
# Processing URL_ID: Netclan20241145
# Processing URL_ID: Netclan20241146
# Processing URL_ID: Netclan20241147
# Processing URL_ID: Netclan20241148
# Processing URL_ID: Netclan20241149
# Processing URL_ID: Netclan20241150
# Processing URL_ID: Netclan20241151
# Processing URL_ID: Netclan20241152
# Processing URL_ID: Netclan20241153
# Processing URL_ID: Netclan20241154
# Processing URL_ID: Netclan20241155
# Processing URL_ID: Netclan20241156
# Processing URL_ID: Netclan20241157
# Processing URL_ID: Netclan20241158
# Processing URL_ID: Netclan20241159
# Processing URL_ID: Netclan20241160
# Processing URL_ID: Netclan20241161
# Processing URL_ID: Netclan20241162
# Processing URL_ID: Netclan20241163
# Processing complete! Results saved in Output.xlsx
